# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### what you need to learn
# - loading data
# - selection
#      - cols
#      - rows
# - manipulation
#     - add column
#     - remove columns
#     - rename columns
#     - change data types
#     - delete data
#     - remove duplicates
#     - sort
#     - group
#     - pivot
#     - merge
# - visualisation
#     - line plot
#     - bar plot
#     - histogram
#     - box plot
#     - scatter plot
#     - pie chart
#     - heatmap
#     - word cloud

# %%
penguins = sns.load_dataset('penguins')
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %% [markdown]
# - analysis
#      - univariate analysis
#      - bi-variate analysis
#      - multi-variate analysis

# %% [markdown]
# - loading data
#     - custom data from a variable
#     - excel data
#     - csv/  json/ etc
#     - database(sql)

# %%
students = {
    'name':['Vaibhav','Siya','Aman','Amjad','Sneha','Aditi','Bhupendra'],
    'college':['SRMCEM','SRMCEM','KMCLU','KMCLU','CU','SRMCEM','SRMCEM'],
    'dob':['25 jan','2 feb','2 april','16 aug','16 sep','12 dec','22 may']
}
sdf = pd.DataFrame(students)
sdf
# Out:
#         name college      dob
# 0    Vaibhav  SRMCEM   25 jan
# 1       Siya  SRMCEM    2 feb
# 2       Aman   KMCLU  2 april
# 3      Amjad   KMCLU   16 aug
# 4      Sneha      CU   16 sep
# 5      Aditi  SRMCEM   12 dec
# 6  Bhupendra  SRMCEM   22 may

# %%
data = pd.read_csv('/Users/Amjad/Documents/Pandas/friends.csv')
data
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\DELL\OneDrive\2023-SEP--PY-DS-master\2023-SEP--PY-DS-master\data analysis\pandas.ipynb Cell 7 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/DELL/OneDrive/2023-SEP--PY-DS-master/2023-SEP--PY-DS-master/data%20analysis/pandas.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> data = pd.read_csv('/Users/Amjad/Documents/Pandas/friends.csv')
#       <a href='vscode-notebook-cell:/c%3A/Users/DELL/OneDrive/2023-SEP--PY-DS-master/2023-SEP--PY-DS-master/data%20analysis/pandas.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a> data
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  5 non-null      int64
#  1   Name        5 non-null      object
#  2   Marks       5 non-null      int64
#  3   city        5 non-null      object
# dtypes: int64(2), object(2)
# memory usage: 292.0+ bytes

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Name', 'Marks', 'city'], dtype='object')

# %%
data.columns.tolist()
# Out:
# ['Unnamed: 0', 'Name', 'Marks', 'city']

# %%
data['Marks'] # column selection as dictionary key
# Out:
# 0    12
# 1    34
# 2    45
# 3    67
# 4    45
# Name: Marks, dtype: int64

# %%
data.city  # column selection as object attributes
# Out:
# 0             England
# 1           Chandauli
# 2    Ghundi Kund Kala
# 3            Ghazipur
# 4            Ghazipur
# Name: city, dtype: object

# %%
data[['Name','city']]  # column selection as list of columns
# Out:
#      Name              city
# 0   Harry           England
# 1  Ashraf         Chandauli
# 2    Saif  Ghundi Kund Kala
# 3   Vinay          Ghazipur
# 4  Deepak          Ghazipur

# %% [markdown]
# # operation between columns

# %%
data['Name'] * data['Unnamed: 0']
# Out:
# 0
# 1                      Ashraf
# 2                    SaifSaif
# 3             VinayVinayVinay
# 4    DeepakDeepakDeepakDeepak
# dtype: object

# %% [markdown]
# # adding elements

# %%
# data['new_col'] = expressions 
data['total'] = data['Name'] * data['Unnamed: 0']
data
# Out:
#    Unnamed: 0    Name  Marks              city                     total
# 0           0   Harry     12           England
# 1           1  Ashraf     34         Chandauli                    Ashraf
# 2           2    Saif     45  Ghundi Kund Kala                  SaifSaif
# 3           3   Vinay     67          Ghazipur           VinayVinayVinay
# 4           4  Deepak     45          Ghazipur  DeepakDeepakDeepakDeepak

# %%
data['crap'] = 'some crap'
data
# Out:
#    Unnamed: 0    Name  Marks              city                     total  \
# 0           0   Harry     12           England
# 1           1  Ashraf     34         Chandauli                    Ashraf
# 2           2    Saif     45  Ghundi Kund Kala                  SaifSaif
# 3           3   Vinay     67          Ghazipur           VinayVinayVinay
# 4           4  Deepak     45          Ghazipur  DeepakDeepakDeepakDeepak
#
#         crap
# 0  some crap
# 1  some crap
# 2  some crap
# 3  some crap
# 4  some crap

# %% [markdown]
# # removing element

# %%
data.drop(columns=['crap'], inplace=True)
data
# Out:
#    Unnamed: 0    Name  Marks              city                     total
# 0           0   Harry     12           England
# 1           1  Ashraf     34         Chandauli                    Ashraf
# 2           2    Saif     45  Ghundi Kund Kala                  SaifSaif
# 3           3   Vinay     67          Ghazipur           VinayVinayVinay
# 4           4  Deepak     45          Ghazipur  DeepakDeepakDeepakDeepak

# %%
data.iloc[0]
# Out:
# Unnamed: 0          0
# Name            Harry
# Marks              12
# city          England
# total
# Name: 0, dtype: object

# %%
data.iloc[:2] # first two rows
# Out:
#    Unnamed: 0    Name  Marks       city   total
# 0           0   Harry     12    England
# 1           1  Ashraf     34  Chandauli  Ashraf

# %%
data.drop(index=[2])
# Out:
#    Unnamed: 0    Name  Marks       city                     total
# 0           0   Harry     12    England
# 1           1  Ashraf     34  Chandauli                    Ashraf
# 3           3   Vinay     67   Ghazipur           VinayVinayVinay
# 4           4  Deepak     45   Ghazipur  DeepakDeepakDeepakDeepak

# %%
data.drop(index=[0,3])
# Out:
#    Unnamed: 0    Name  Marks              city                     total
# 1           1  Ashraf     34         Chandauli                    Ashraf
# 2           2    Saif     45  Ghundi Kund Kala                  SaifSaif
# 4           4  Deepak     45          Ghazipur  DeepakDeepakDeepakDeepak

# %%
sdf
# Out:
#         name college      dob
# 0    Vaibhav  SRMCEM   25 jan
# 1       Siya  SRMCEM    2 feb
# 2       Aman   KMCLU  2 april
# 3      Amjad   KMCLU   16 aug
# 4      Sneha      CU   16 sep
# 5      Aditi  SRMCEM   12 dec
# 6  Bhupendra  SRMCEM   22 may

# %%
sdf.drop(index=[0,1])
# Out:
#         name college      dob
# 2       Aman   KMCLU  2 april
# 3      Amjad   KMCLU   16 aug
# 4      Sneha      CU   16 sep
# 5      Aditi  SRMCEM   12 dec
# 6  Bhupendra  SRMCEM   22 may

# %%
sdf.drop(index=[3], inplace=True)

# %%
sdf
# Out:
#         name college      dob
# 0    Vaibhav  SRMCEM   25 jan
# 1       Siya  SRMCEM    2 feb
# 2       Aman   KMCLU  2 april
# 4      Sneha      CU   16 sep
# 5      Aditi  SRMCEM   12 dec
# 6  Bhupendra  SRMCEM   22 may

# %%
data['Marks'] = data['Marks'] - 5

# %%
data
# Out:
#    Unnamed: 0    Name  Marks              city                     total
# 0           0   Harry      7           England
# 1           1  Ashraf     29         Chandauli                    Ashraf
# 2           2    Saif     40  Ghundi Kund Kala                  SaifSaif
# 3           3   Vinay     62          Ghazipur           VinayVinayVinay
# 4           4  Deepak     40          Ghazipur  DeepakDeepakDeepakDeepak

# %%
data.columns.tolist()
# Out:
# ['Unnamed: 0', 'Name', 'Marks', 'city', 'total']

# %%
data.rename(
    mapper={
        'Unnamed: 0': 'Rank',
        'Name': 'Name of Students',
        'Marks': 'Marks gain',
        'city': 'Place',
    },
    axis=1,
    inplace=True
)
data
# Out:
#    Rank Name of Students  Marks gain             Place  \
# 0     0            Harry           7           England
# 1     1           Ashraf          29         Chandauli
# 2     2             Saif          40  Ghundi Kund Kala
# 3     3            Vinay          62          Ghazipur
# 4     4           Deepak          40          Ghazipur
#
#                       total
# 0
# 1                    Ashraf
# 2                  SaifSaif
# 3           VinayVinayVinay
# 4  DeepakDeepakDeepakDeepak

# %% [markdown]
# 23-oct-23
# - operation
#     - delete data
#         - columns
#         - indexes
#     - remove duplicates
#     - sort
#     - group
#     - pivot
#     - merge

# %%
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
penguins.drop(columns="body_mass_g")
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#         sex
# 0      Male
# 1    Female
# 2    Female
# 3       NaN
# 4    Female
# ...

# %%
penguins.drop(columns=['island','body_mass_g'])
# Out:
#     species  bill_length_mm  bill_depth_mm  flipper_length_mm     sex
# 0    Adelie            39.1           18.7              181.0    Male
# 1    Adelie            39.5           17.4              186.0  Female
# 2    Adelie            40.3           18.0              195.0  Female
# 3    Adelie             NaN            NaN                NaN     NaN
# 4    Adelie            36.7           19.3              193.0  Female
# ..      ...             ...            ...                ...     ...
# 339  Gentoo             NaN            NaN                NaN     NaN
# 340  Gentoo            46.8           14.3              215.0  Female
# 341  Gentoo            50.4           15.7              222.0    Male
# 342  Gentoo            45.2           14.8              212.0  Female
# 343  Gentoo            49.9           16.1              213.0    Male
#
# [344 rows x 5 columns]

# %%
penguins.drop(index=2)  # drop row 3rd
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
penguins.drop(index=[0,1,2,3,4])  # drop multiple row
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 5    Adelie  Torgersen            39.3           20.6              190.0
# 6    Adelie  Torgersen            38.9           17.8              181.0
# 7    Adelie  Torgersen            39.2           19.6              195.0
# 8    Adelie  Torgersen            34.1           18.1              193.0
# 9    Adelie  Torgersen            42.0           20.2              190.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 5         3650.0    Male
# 6         3625.0  Female
# ...

# %%
penguins.drop(index=range(10))  # drop multiple row using range
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 10   Adelie  Torgersen            37.8           17.1              186.0
# 11   Adelie  Torgersen            37.8           17.3              180.0
# 12   Adelie  Torgersen            41.1           17.6              182.0
# 13   Adelie  Torgersen            38.6           21.2              191.0
# 14   Adelie  Torgersen            34.6           21.1              198.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 10        3300.0     NaN
# 11        3700.0     NaN
# ...

# %%
np.nan
# Out:
# nan

# %% [markdown]
# find the missing number of values in each columns

# %%
penguins.isnull().sum()
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# dtype: int64

# %%
sns.heatmap(penguins.isnull(), cbar=False)  # overall null value visualization
# Out:
# <Axes: >

# %%
penguins.isnull().sum().plot(kind='bar')  # column wise null value visualization
# Out:
# <Axes: >

# %%
penguins.dropna()   # drop rows with null values
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
penguins.shape
# Out:
# (344, 7)

# %%
penguins.dropna()
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
penguins.dropna(inplace=True)
print(penguins.shape)
# Out:
# (333, 7)

# %%
penguins.drop_duplicates(subset=['bill_length_mm'])
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 326  Gentoo     Biscoe            41.7           14.7              210.0
# 327  Gentoo     Biscoe            53.4           15.8              219.0
# 335  Gentoo     Biscoe            55.1           16.0              230.0
# 337  Gentoo     Biscoe            48.8           16.2              222.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
penguins.sort_values(by='sex')
# Out:
#        species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 172  Chinstrap   Dream            42.4           17.3              181.0
# 136     Adelie   Dream            35.6           17.5              191.0
# 138     Adelie   Dream            37.0           16.5              185.0
# 272     Gentoo  Biscoe            45.1           14.4              210.0
# 140     Adelie   Dream            40.2           17.1              193.0
# ..         ...     ...             ...            ...                ...
# 163  Chinstrap   Dream            51.7           20.3              194.0
# 165  Chinstrap   Dream            52.0           18.1              201.0
# 167  Chinstrap   Dream            50.5           19.6              201.0
# 145     Adelie   Dream            39.0           18.7              185.0
# 343     Gentoo  Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 172       3600.0  Female
# 136       3175.0  Female
# ...

# %%
penguins.sort_values(by=['sex','island'])
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 20   Adelie     Biscoe            37.8           18.3              174.0
# 22   Adelie     Biscoe            35.9           19.2              189.0
# 25   Adelie     Biscoe            35.3           18.9              187.0
# 27   Adelie     Biscoe            40.5           17.9              187.0
# 28   Adelie     Biscoe            37.9           18.6              172.0
# ..      ...        ...             ...            ...                ...
# 123  Adelie  Torgersen            41.4           18.5              202.0
# 125  Adelie  Torgersen            40.6           19.0              199.0
# 127  Adelie  Torgersen            41.5           18.3              195.0
# 129  Adelie  Torgersen            44.1           18.0              210.0
# 131  Adelie  Torgersen            43.1           19.2              197.0
#
#      body_mass_g     sex
# 20        3400.0  Female
# 22        3800.0  Female
# ...

# %% [markdown]
# datatypes in pandas
# - int
# - float
# - boolean
# - string (not understood by pandas by default, unless you specify)
# - datetime
# - object
# - category

# %%
penguins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 333 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            333 non-null    object
#  1   island             333 non-null    object
#  2   bill_length_mm     333 non-null    float64
#  3   bill_depth_mm      333 non-null    float64
#  4   flipper_length_mm  333 non-null    float64
#  5   body_mass_g        333 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 20.8+ KB

# %%
penguins.dtypes
# Out:
# species               object
# island                object
# bill_length_mm       float64
# bill_depth_mm        float64
# flipper_length_mm    float64
# body_mass_g          float64
# sex                   object
# dtype: object

# %%
penguins.select_dtypes(include='number')
# Out:
#      bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# 0              39.1           18.7              181.0       3750.0
# 1              39.5           17.4              186.0       3800.0
# 2              40.3           18.0              195.0       3250.0
# 4              36.7           19.3              193.0       3450.0
# 5              39.3           20.6              190.0       3650.0
# ..              ...            ...                ...          ...
# 338            47.2           13.7              214.0       4925.0
# 340            46.8           14.3              215.0       4850.0
# 341            50.4           15.7              222.0       5750.0
# 342            45.2           14.8              212.0       5200.0
# 343            49.9           16.1              213.0       5400.0
#
# [333 rows x 4 columns]

# %%
penguins.select_dtypes(include='object')
# Out:
#     species     island     sex
# 0    Adelie  Torgersen    Male
# 1    Adelie  Torgersen  Female
# 2    Adelie  Torgersen  Female
# 4    Adelie  Torgersen  Female
# 5    Adelie  Torgersen    Male
# ..      ...        ...     ...
# 338  Gentoo     Biscoe  Female
# 340  Gentoo     Biscoe  Female
# 341  Gentoo     Biscoe    Male
# 342  Gentoo     Biscoe  Female
# 343  Gentoo     Biscoe    Male
#
# [333 rows x 3 columns]

# %%
penguins.select_dtypes(exclude='number')
# Out:
#     species     island     sex
# 0    Adelie  Torgersen    Male
# 1    Adelie  Torgersen  Female
# 2    Adelie  Torgersen  Female
# 4    Adelie  Torgersen  Female
# 5    Adelie  Torgersen    Male
# ..      ...        ...     ...
# 338  Gentoo     Biscoe  Female
# 340  Gentoo     Biscoe  Female
# 341  Gentoo     Biscoe    Male
# 342  Gentoo     Biscoe  Female
# 343  Gentoo     Biscoe    Male
#
# [333 rows x 3 columns]

# %% [markdown]
# change data types of column

# %%
penguins['island'].astype('category') # not actually applied on the column
# Out:
# 0      Torgersen
# 1      Torgersen
# 2      Torgersen
# 4      Torgersen
# 5      Torgersen
#          ...
# 338       Biscoe
# 340       Biscoe
# 341       Biscoe
# 342       Biscoe
# 343       Biscoe
# Name: island, Length: 333, dtype: category
# Categories (3, object): ['Biscoe', 'Dream', 'Torgersen']

# %%
penguins['island'] = penguins['island'].astype('category')  # casting object to category

# %%
penguins.dtypes
# Out:
# species                object
# island               category
# bill_length_mm        float64
# bill_depth_mm         float64
# flipper_length_mm     float64
# body_mass_g           float64
# sex                    object
# dtype: object

# %%
penguins.sex = penguins.sex.astype('bool')
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 4  Adelie  Torgersen            36.7           19.3              193.0
# 5  Adelie  Torgersen            39.3           20.6              190.0
#
#    body_mass_g   sex
# 0       3750.0  True
# 1       3800.0  True
# 2       3250.0  True
# 4       3450.0  True
# 5       3650.0  True

# %% [markdown]
# simple visualization
# - for numerial data
#    - line plot  -> `.plot()`
#    - bar plot  -> `.plot(kind='bar')`
#    - hist plot  -> `.hist()`

# %%
penguins['bill_depth_mm'].hist()
# Out:
# <Axes: >

# %%
penguins['bill_depth_mm'].plot(figsize=(15,5))
# Out:
# <Axes: >

# %%
penguins['bill_depth_mm'].plot(kind='area', figsize= (15,5))
# Out:
# <Axes: >

# %%
penguins['bill_depth_mm'].plot(kind='box', figsize= (15,5))
# Out:
# <Axes: >

# %%
penguins['bill_depth_mm'].plot(kind='box', figsize= (5,3), vert=False)
# Out:
# <Axes: >

# %%
penguins['island'].value_counts()
# Out:
# island
# Biscoe       163
# Dream        123
# Torgersen     47
# Name: count, dtype: int64

# %%
penguins['island'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='island'>

# %%
penguins['bill_length_mm'].hist()
# Out:
# <Axes: >

# %%
penguins['bill_length_mm'].plot(figsize=(10,5))
# Out:
# <Axes: >

# %%
penguins['bill_length_mm'].plot(kind='area',figsize=(10,5))
# Out:
# <Axes: >

# %%
penguins['bill_length_mm'].plot(kind='box',figsize=(10,5))
# Out:
# <Axes: >

# %% [markdown]
# comparing univariate data

# %%
penguins[['bill_depth_mm','bill_length_mm']]
# Out:
#      bill_depth_mm  bill_length_mm
# 0             18.7            39.1
# 1             17.4            39.5
# 2             18.0            40.3
# 4             19.3            36.7
# 5             20.6            39.3
# ..             ...             ...
# 338           13.7            47.2
# 340           14.3            46.8
# 341           15.7            50.4
# 342           14.8            45.2
# 343           16.1            49.9
#
# [333 rows x 2 columns]

# %%
penguins[['bill_depth_mm','bill_length_mm']].plot()
# Out:
# <Axes: >

# %%
penguins[['bill_depth_mm','bill_length_mm']].plot(kind='box', figsize=(15,5))
# Out:
# <Axes: >

# %%
penguins[['bill_depth_mm','bill_length_mm']].hist(bins=20, figsize=(15,5))
# Out:
# array([[<Axes: title={'center': 'bill_depth_mm'}>,
#         <Axes: title={'center': 'bill_length_mm'}>]], dtype=object)

# %%
penguins[['bill_depth_mm','bill_length_mm']].plot(layout=(1,2), subplots=True, figsize=(15,5))
# Out:
# array([[<Axes: >, <Axes: >]], dtype=object)

# %%
penguins[['bill_depth_mm','bill_length_mm','flipper_length_mm']].plot(layout=(1,3), subplots=True, figsize=(15,5))
# Out:
# array([[<Axes: >, <Axes: >, <Axes: >]], dtype=object)

# %% [markdown]
# the power of seaborn - better visualization

# %%
sns.displot(data=penguins, x = 'bill_depth_mm')

# %%
sns.displot(data=penguins, x = 'bill_depth_mm', hue='island')

# %%
sns.displot(data=penguins, x = 'body_mass_g',hue='island')

# %%
sns.countplot(data=penguins, x = 'island')
# Out:
# <Axes: xlabel='island', ylabel='count'>

# %%
sns.countplot(data=penguins, x='island', hue='species')
# Out:
# <Axes: xlabel='island', ylabel='count'>

# %% [markdown]
# bivariate analysis
# - scatter plot
# - violin plot(alternative to box plot)
# - pair plot

# %%
sns.scatterplot(data=penguins, x='bill_length_mm', y='bill_depth_mm')
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %%
sns.set_palette('hot')

# %%
sns.scatterplot(data=penguins, x='bill_length_mm', y='bill_depth_mm', hue='species')
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %%
sns.scatterplot(data=penguins, x='bill_length_mm', y='bill_depth_mm', hue='island', palette='cool')
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %%
sns.color_palette()
# Out:
# [(0.41221438595965454, 0.0, 0.0),
#  (0.7931236159737438, 0.0, 0.0),
#  (1.0, 0.16372618247436524, 0.0),
#  (1.0, 0.544607916482724, 0.0),
#  (1.0, 0.9151955495719379, 0.0),
#  (1.0, 1.0, 0.44411709117591475)]

# %%
sns.set_theme(style="darkgrid")

# %%
tips = sns.load_dataset("tips")
sns.relplot(data=tips, x="total_bill", y="tip")

# %%
sns.relplot(data=tips, x="total_bill", y="tip", hue="smoker")

# %%
sns.relplot(
    data=tips,
    x="total_bill", y="tip", hue="smoker", style="smoker"
)

# %%
sns.relplot(
    data=tips,
    x="total_bill", y="tip", hue="smoker", style="time",
)

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
tips.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
sns.relplot(
    data=tips, x="total_bill", y="tip",
    size="size", sizes=(10, 200)
)

# %%
fmri = sns.load_dataset("fmri")
sns.relplot(data=fmri, x="timepoint", y="signal", kind="line")

# %%
fmri.dtypes
# Out:
# subject       object
# timepoint      int64
# event         object
# region        object
# signal       float64
# dtype: object

# %%
sns.relplot(
    data=fmri, kind="line",
    x="timepoint", y="signal", errorbar=None,
)

# %%
fmri = sns.load_dataset("fmri")
sns.relplot(data=fmri, x="subject", y="signal", kind="line")

# %%
fmri = sns.load_dataset("fmri")
sns.relplot(data=fmri, x="subject", y="signal", kind="line",errorbar='sd',estimator=None)

# %%
sns.relplot(
    data=fmri, kind="line",
    x="timepoint", y="signal", hue="event",
)

# %%
sns.relplot(
    data=fmri, kind="line",
    x="timepoint", y="signal",
    hue="region", style="event",
)

# %%
sns.relplot(
    data=fmri, kind="line",
    x="timepoint", y="signal", hue="region", style="event",
    dashes=False, markers=True,
)

# %%
fmri.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1064 entries, 0 to 1063
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   subject    1064 non-null   object
#  1   timepoint  1064 non-null   int64
#  2   event      1064 non-null   object
#  3   region     1064 non-null   object
#  4   signal     1064 non-null   float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 41.7+ KB

# %%
sns.relplot(
    data=fmri, kind="line",
    x="timepoint", y="signal", hue="region", style="event",
    dashes=False, markers=True,
)
